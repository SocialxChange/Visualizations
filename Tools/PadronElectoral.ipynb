# %% [markdown]
# <a href="https://colab.research.google.com/github/SocialxChange/Visualizations/blob/master/Tools/PadronElectoral.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Descarga Padrón Electoral
#
# Para el 2013 [este repositorio](https://github.com/aifuenzalida/Servel-Extract) extrae los datos de los PDF.
#
# El siguiente script descarga el padrón siguiento [el repo aifuenzalida/padron-servel](https://github.com/aifuenzalida/padron-servel/blob/master/servel_download.py)

# %%
import re
import os
import requests
import shutil
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import urllib.request
from pathlib import Path


# Variables
url_padron = "https://www.servel.cl/padron-electoral-definitivo-y-nomina-de-inhabilitados-3/"
output_folder = "output"


# Open and parse page
request = requests.get(url_padron)
page = BeautifulSoup(request.text, 'lxml')


# Find all PDF files links
main_content = page.find(class_='tab-content')
links = main_content.find_all('a', href=re.compile("pdf"))

full_links = []

for link in links:
    full_link = urljoin(url_padron, link['href'])
    full_links.append(full_link)

print("Found " + str(full_links.count) + " links")
# Out:
# Found <built-in method count of list object at 0x7f027bca1690> links

# %% [markdown]
# Esta descarga toma 20 minutos:

# %%
cwd = os.getcwd()
output_path = cwd + '/' + output_folder
Path(output_path).mkdir(exist_ok=True)

for full_link in full_links:
    print("Downloading " + full_link)
    local_filename = full_link.split('/')[-1]

    with requests.get(full_link, stream=True) as r:
        with open(output_path + '/' + local_filename, 'wb') as f:
            shutil.copyfileobj(r.raw, f)

print("End")
# Out:
# Downloading https://cdn.servel.cl/padron/A15101.pdf
# Downloading https://cdn.servel.cl/padron/A15102.pdf
# Downloading https://cdn.servel.cl/padron/A15202.pdf
# Downloading https://cdn.servel.cl/padron/A15201.pdf
# Downloading https://cdn.servel.cl/padron/A01107.pdf
# Downloading https://cdn.servel.cl/padron/A01402.pdf
# Downloading https://cdn.servel.cl/padron/A01403.pdf
# Downloading https://cdn.servel.cl/padron/A01404.pdf
# Downloading https://cdn.servel.cl/padron/A01101.pdf
# Downloading https://cdn.servel.cl/padron/A01405.pdf
# Downloading https://cdn.servel.cl/padron/A01401.pdf
# Downloading https://cdn.servel.cl/padron/A02101.pdf
# Downloading https://cdn.servel.cl/padron/A02201.pdf
# Downloading https://cdn.servel.cl/padron/A02302.pdf
# Downloading https://cdn.servel.cl/padron/A02102.pdf
# Downloading https://cdn.servel.cl/padron/A02202.pdf
# Downloading https://cdn.servel.cl/padron/A02203.pdf
# Downloading https://cdn.servel.cl/padron/A02103.pdf
# Downloading https://cdn.servel.cl/padron/A02104.pdf
# Downloading https://cdn.servel.cl/padron/A02301.pdf
# Downloading https://cdn.servel.cl/padron/A03302.pdf
# Downloading https://cdn.servel.cl/padron/A03102.pdf
# Downloading https://cdn.servel.cl/padron/A03201.pdf
# Downloading https://cdn.servel.cl/padron/A03101.pdf
# Downloading https://cdn.servel.cl/padron/A03202.pdf
# Downloading https://cdn.servel.cl/padron/A03303.pdf
# Downloading https://cdn.servel.cl/padron/A03304.pdf
# Downloading https://cdn.servel.cl/padron/A03103.pdf
# Downloading https://cdn.servel.cl/padron/A03301.pdf
# Downloading https://cdn.servel.cl/padron/A04103.pdf
# Downloading https://cdn.servel.cl/padron/A04202.pdf
# Downloading https://cdn.servel.cl/padron/A04302.pdf
# Downloading https://cdn.servel.cl/padron/A04102.pdf
# Downloading https://cdn.servel.cl/padron/A04201.pdf
# Downloading https://cdn.servel.cl/padron/A04104.pdf
# Downloading https://cdn.servel.cl/padron/A04101.pdf
# Downloading https://cdn.servel.cl/padron/A04203.pdf
# Downloading https://cdn.servel.cl/padron/A04303.pdf
# Downloading https://cdn.servel.cl/padron/A04301.pdf
# Downloading https://cdn.servel.cl/padron/A04105.pdf
# Downloading https://cdn.servel.cl/padron/A04304.pdf
# Downloading https://cdn.servel.cl/padron/A04305.pdf
# Downloading https://cdn.servel.cl/padron/A04204.pdf
# Downloading https://cdn.servel.cl/padron/A04106.pdf
# Downloading https://cdn.servel.cl/padron/A05602.pdf
# Downloading https://cdn.servel.cl/padron/A05402.pdf
# Downloading https://cdn.servel.cl/padron/A05502.pdf
# Downloading https://cdn.servel.cl/padron/A05302.pdf
# Downloading https://cdn.servel.cl/padron/A05603.pdf
# Downloading https://cdn.servel.cl/padron/A05102.pdf
# Downloading https://cdn.servel.cl/padron/A05702.pdf
# Downloading https://cdn.servel.cl/padron/A05103.pdf
# Downloading https://cdn.servel.cl/padron/A05604.pdf
# Downloading https://cdn.servel.cl/padron/A05605.pdf
# Downloading https://cdn.servel.cl/padron/A05503.pdf
# Downloading https://cdn.servel.cl/padron/A05201.pdf
# Downloading https://cdn.servel.cl/padron/A05104.pdf
# Downloading https://cdn.servel.cl/padron/A05504.pdf
# Downloading https://cdn.servel.cl/padron/A05401.pdf
# Downloading https://cdn.servel.cl/padron/A05802.pdf
# Downloading https://cdn.servel.cl/padron/A05703.pdf
# Downloading https://cdn.servel.cl/padron/A05301.pdf
# Downloading https://cdn.servel.cl/padron/A05506.pdf
# Downloading https://cdn.servel.cl/padron/A05803.pdf
# Downloading https://cdn.servel.cl/padron/A05704.pdf
# Downloading https://cdn.servel.cl/padron/A05403.pdf
# Downloading https://cdn.servel.cl/padron/A05404.pdf
# Downloading https://cdn.servel.cl/padron/A05105.pdf
# Downloading https://cdn.servel.cl/padron/A05705.pdf
# Downloading https://cdn.servel.cl/padron/A05501.pdf
# Downloading https://cdn.servel.cl/padron/A05801.pdf
# Downloading https://cdn.servel.cl/padron/A05107.pdf
# Downloading https://cdn.servel.cl/padron/A05303.pdf
# Downloading https://cdn.servel.cl/padron/A05601.pdf
# Downloading https://cdn.servel.cl/padron/A05304.pdf
# Downloading https://cdn.servel.cl/padron/A05701.pdf
# Downloading https://cdn.servel.cl/padron/A05706.pdf
# Downloading https://cdn.servel.cl/padron/A05606.pdf
# Downloading https://cdn.servel.cl/padron/A05101.pdf
# Downloading https://cdn.servel.cl/padron/A05804.pdf
# Downloading https://cdn.servel.cl/padron/A05109.pdf
# Downloading https://cdn.servel.cl/padron/A05405.pdf
# Downloading https://cdn.servel.cl/padron/A13502.pdf
# Downloading https://cdn.servel.cl/padron/A13402.pdf
# Downloading https://cdn.servel.cl/padron/A13403.pdf
# Downloading https://cdn.servel.cl/padron/A13102.pdf
# Downloading https://cdn.servel.cl/padron/A13103.pdf
# Downloading https://cdn.servel.cl/padron/A13301.pdf
# Downloading https://cdn.servel.cl/padron/A13104.pdf
# Downloading https://cdn.servel.cl/padron/A13503.pdf
# Downloading https://cdn.servel.cl/padron/A13105.pdf
# Downloading https://cdn.servel.cl/padron/A13602.pdf
# Downloading https://cdn.servel.cl/padron/A13106.pdf
# Downloading https://cdn.servel.cl/padron/A13107.pdf
# Downloading https://cdn.servel.cl/padron/A13108.pdf
# Downloading https://cdn.servel.cl/padron/A13603.pdf
# Downloading https://cdn.servel.cl/padron/A13109.pdf
# Downloading https://cdn.servel.cl/padron/A13110.pdf
# Downloading https://cdn.servel.cl/padron/A13111.pdf
# Downloading https://cdn.servel.cl/padron/A13112.pdf
# Downloading https://cdn.servel.cl/padron/A13113.pdf
# Downloading https://cdn.servel.cl/padron/A13302.pdf
# Downloading https://cdn.servel.cl/padron/A13114.pdf
# Downloading https://cdn.servel.cl/padron/A13115.pdf
# Downloading https://cdn.servel.cl/padron/A13116.pdf
# Downloading https://cdn.servel.cl/padron/A13117.pdf
# Downloading https://cdn.servel.cl/padron/A13118.pdf
# Downloading https://cdn.servel.cl/padron/A13119.pdf
# Downloading https://cdn.servel.cl/padron/A13504.pdf
# Downloading https://cdn.servel.cl/padron/A13501.pdf
# Downloading https://cdn.servel.cl/padron/A13120.pdf
# Downloading https://cdn.servel.cl/padron/A13604.pdf
# Downloading https://cdn.servel.cl/padron/A13404.pdf
# Downloading https://cdn.servel.cl/padron/A13121.pdf
# Downloading https://cdn.servel.cl/padron/A13605.pdf
# Downloading https://cdn.servel.cl/padron/A13122.pdf
# Downloading https://cdn.servel.cl/padron/A13202.pdf
# Downloading https://cdn.servel.cl/padron/A13123.pdf
# Downloading https://cdn.servel.cl/padron/A13124.pdf
# Downloading https://cdn.servel.cl/padron/A13201.pdf
# Downloading https://cdn.servel.cl/padron/A13125.pdf
# Downloading https://cdn.servel.cl/padron/A13126.pdf
# Downloading https://cdn.servel.cl/padron/A13127.pdf
# Downloading https://cdn.servel.cl/padron/A13128.pdf
# Downloading https://cdn.servel.cl/padron/A13401.pdf
# Downloading https://cdn.servel.cl/padron/A13129.pdf
# Downloading https://cdn.servel.cl/padron/A13203.pdf
# Downloading https://cdn.servel.cl/padron/A13130.pdf
# Downloading https://cdn.servel.cl/padron/A13505.pdf
# Downloading https://cdn.servel.cl/padron/A13131.pdf
# Downloading https://cdn.servel.cl/padron/A13101.pdf
# Downloading https://cdn.servel.cl/padron/A13601.pdf
# Downloading https://cdn.servel.cl/padron/A13303.pdf
# Downloading https://cdn.servel.cl/padron/A13132.pdf
# Downloading https://cdn.servel.cl/padron/A06302.pdf
# Downloading https://cdn.servel.cl/padron/A06303.pdf
# Downloading https://cdn.servel.cl/padron/A06102.pdf
# Downloading https://cdn.servel.cl/padron/A06103.pdf
# Downloading https://cdn.servel.cl/padron/A06104.pdf
# Downloading https://cdn.servel.cl/padron/A06105.pdf
# Downloading https://cdn.servel.cl/padron/A06106.pdf
# Downloading https://cdn.servel.cl/padron/A06202.pdf
# Downloading https://cdn.servel.cl/padron/A06107.pdf
# Downloading https://cdn.servel.cl/padron/A06203.pdf
# Downloading https://cdn.servel.cl/padron/A06304.pdf
# Downloading https://cdn.servel.cl/padron/A06108.pdf
# Downloading https://cdn.servel.cl/padron/A06109.pdf
# Downloading https://cdn.servel.cl/padron/A06204.pdf
# Downloading https://cdn.servel.cl/padron/A06110.pdf
# Downloading https://cdn.servel.cl/padron/A06305.pdf
# Downloading https://cdn.servel.cl/padron/A06205.pdf
# Downloading https://cdn.servel.cl/padron/A06111.pdf
# Downloading https://cdn.servel.cl/padron/A06306.pdf
# Downloading https://cdn.servel.cl/padron/A06206.pdf
# Downloading https://cdn.servel.cl/padron/A06307.pdf
# Downloading https://cdn.servel.cl/padron/A06112.pdf
# Downloading https://cdn.servel.cl/padron/A06113.pdf
# Downloading https://cdn.servel.cl/padron/A06201.pdf
# Downloading https://cdn.servel.cl/padron/A06308.pdf
# Downloading https://cdn.servel.cl/padron/A06309.pdf
# Downloading https://cdn.servel.cl/padron/A06114.pdf
# Downloading https://cdn.servel.cl/padron/A06101.pdf
# Downloading https://cdn.servel.cl/padron/A06115.pdf
# Downloading https://cdn.servel.cl/padron/A06116.pdf
# Downloading https://cdn.servel.cl/padron/A06301.pdf
# Downloading https://cdn.servel.cl/padron/A06117.pdf
# Downloading https://cdn.servel.cl/padron/A06310.pdf
# Downloading https://cdn.servel.cl/padron/A07201.pdf
# Downloading https://cdn.servel.cl/padron/A07202.pdf
# Downloading https://cdn.servel.cl/padron/A07402.pdf
# Downloading https://cdn.servel.cl/padron/A07102.pdf
# Downloading https://cdn.servel.cl/padron/A07103.pdf
# Downloading https://cdn.servel.cl/padron/A07301.pdf
# Downloading https://cdn.servel.cl/padron/A07104.pdf
# Downloading https://cdn.servel.cl/padron/A07302.pdf
# Downloading https://cdn.servel.cl/padron/A07303.pdf
# Downloading https://cdn.servel.cl/padron/A07401.pdf
# Downloading https://cdn.servel.cl/padron/A07403.pdf
# Downloading https://cdn.servel.cl/padron/A07105.pdf
# Downloading https://cdn.servel.cl/padron/A07304.pdf
# Downloading https://cdn.servel.cl/padron/A07404.pdf
# Downloading https://cdn.servel.cl/padron/A07106.pdf
# Downloading https://cdn.servel.cl/padron/A07203.pdf
# Downloading https://cdn.servel.cl/padron/A07107.pdf
# Downloading https://cdn.servel.cl/padron/A07305.pdf
# Downloading https://cdn.servel.cl/padron/A07405.pdf
# Downloading https://cdn.servel.cl/padron/A07108.pdf
# Downloading https://cdn.servel.cl/padron/A07306.pdf
# Downloading https://cdn.servel.cl/padron/A07307.pdf
# Downloading https://cdn.servel.cl/padron/A07109.pdf
# Downloading https://cdn.servel.cl/padron/A07406.pdf
# Downloading https://cdn.servel.cl/padron/A07110.pdf
# Downloading https://cdn.servel.cl/padron/A07101.pdf
# Downloading https://cdn.servel.cl/padron/A07308.pdf
# Downloading https://cdn.servel.cl/padron/A07309.pdf
# Downloading https://cdn.servel.cl/padron/A07407.pdf
# Downloading https://cdn.servel.cl/padron/A07408.pdf
# Downloading https://cdn.servel.cl/padron/A16102.pdf
# Downloading https://cdn.servel.cl/padron/A16101.pdf
# Downloading https://cdn.servel.cl/padron/A16103.pdf
# Downloading https://cdn.servel.cl/padron/A16202.pdf
# Downloading https://cdn.servel.cl/padron/A16203.pdf
# Downloading https://cdn.servel.cl/padron/A16302.pdf
# Downloading https://cdn.servel.cl/padron/A16104.pdf
# Downloading https://cdn.servel.cl/padron/A16204.pdf
# Downloading https://cdn.servel.cl/padron/A16303.pdf
# Downloading https://cdn.servel.cl/padron/A16105.pdf
# Downloading https://cdn.servel.cl/padron/A16106.pdf
# Downloading https://cdn.servel.cl/padron/A16205.pdf
# Downloading https://cdn.servel.cl/padron/A16107.pdf
# Downloading https://cdn.servel.cl/padron/A16201.pdf
# Downloading https://cdn.servel.cl/padron/A16206.pdf
# Downloading https://cdn.servel.cl/padron/A16301.pdf
# Downloading https://cdn.servel.cl/padron/A16304.pdf
# Downloading https://cdn.servel.cl/padron/A16108.pdf
# Downloading https://cdn.servel.cl/padron/A16305.pdf
# Downloading https://cdn.servel.cl/padron/A16207.pdf
# Downloading https://cdn.servel.cl/padron/A16109.pdf
# Downloading https://cdn.servel.cl/padron/A08314.pdf
# Downloading https://cdn.servel.cl/padron/A08302.pdf
# Downloading https://cdn.servel.cl/padron/A08202.pdf
# Downloading https://cdn.servel.cl/padron/A08303.pdf
# Downloading https://cdn.servel.cl/padron/A08203.pdf
# Downloading https://cdn.servel.cl/padron/A08103.pdf
# Downloading https://cdn.servel.cl/padron/A08101.pdf
# Downloading https://cdn.servel.cl/padron/A08204.pdf
# Downloading https://cdn.servel.cl/padron/A08102.pdf
# Downloading https://cdn.servel.cl/padron/A08205.pdf
# Downloading https://cdn.servel.cl/padron/A08104.pdf
# Downloading https://cdn.servel.cl/padron/A08112.pdf
# Downloading https://cdn.servel.cl/padron/A08105.pdf
# Downloading https://cdn.servel.cl/padron/A08304.pdf
# Downloading https://cdn.servel.cl/padron/A08201.pdf
# Downloading https://cdn.servel.cl/padron/A08206.pdf
# Downloading https://cdn.servel.cl/padron/A08301.pdf
# Downloading https://cdn.servel.cl/padron/A08106.pdf
# Downloading https://cdn.servel.cl/padron/A08305.pdf
# Downloading https://cdn.servel.cl/padron/A08306.pdf
# Downloading https://cdn.servel.cl/padron/A08307.pdf
# Downloading https://cdn.servel.cl/padron/A08107.pdf
# Downloading https://cdn.servel.cl/padron/A08308.pdf
# Downloading https://cdn.servel.cl/padron/A08309.pdf
# Downloading https://cdn.servel.cl/padron/A08108.pdf
# Downloading https://cdn.servel.cl/padron/A08310.pdf
# Downloading https://cdn.servel.cl/padron/A08311.pdf
# Downloading https://cdn.servel.cl/padron/A08109.pdf
# Downloading https://cdn.servel.cl/padron/A08110.pdf
# Downloading https://cdn.servel.cl/padron/A08207.pdf
# Downloading https://cdn.servel.cl/padron/A08111.pdf
# Downloading https://cdn.servel.cl/padron/A08312.pdf
# Downloading https://cdn.servel.cl/padron/A08313.pdf
# Downloading https://cdn.servel.cl/padron/A09201.pdf
# Downloading https://cdn.servel.cl/padron/A09102.pdf
# Downloading https://cdn.servel.cl/padron/A09121.pdf
# Downloading https://cdn.servel.cl/padron/A09202.pdf
# Downloading https://cdn.servel.cl/padron/A09103.pdf
# Downloading https://cdn.servel.cl/padron/A09203.pdf
# Downloading https://cdn.servel.cl/padron/A09104.pdf
# Downloading https://cdn.servel.cl/padron/A09204.pdf
# Downloading https://cdn.servel.cl/padron/A09105.pdf
# Downloading https://cdn.servel.cl/padron/A09106.pdf
# Downloading https://cdn.servel.cl/padron/A09107.pdf
# Downloading https://cdn.servel.cl/padron/A09108.pdf
# Downloading https://cdn.servel.cl/padron/A09109.pdf
# Downloading https://cdn.servel.cl/padron/A09205.pdf
# Downloading https://cdn.servel.cl/padron/A09206.pdf
# Downloading https://cdn.servel.cl/padron/A09207.pdf
# Downloading https://cdn.servel.cl/padron/A09110.pdf
# Downloading https://cdn.servel.cl/padron/A09111.pdf
# Downloading https://cdn.servel.cl/padron/A09112.pdf
# Downloading https://cdn.servel.cl/padron/A09113.pdf
# Downloading https://cdn.servel.cl/padron/A09114.pdf
# Downloading https://cdn.servel.cl/padron/A09115.pdf
# Downloading https://cdn.servel.cl/padron/A09208.pdf
# Downloading https://cdn.servel.cl/padron/A09209.pdf
# Downloading https://cdn.servel.cl/padron/A09116.pdf
# Downloading https://cdn.servel.cl/padron/A09101.pdf
# Downloading https://cdn.servel.cl/padron/A09117.pdf
# Downloading https://cdn.servel.cl/padron/A09118.pdf
# Downloading https://cdn.servel.cl/padron/A09210.pdf
# Downloading https://cdn.servel.cl/padron/A09211.pdf
# Downloading https://cdn.servel.cl/padron/A09119.pdf
# Downloading https://cdn.servel.cl/padron/A09120.pdf
# Downloading https://cdn.servel.cl/padron/A14102.pdf
# Downloading https://cdn.servel.cl/padron/A14202.pdf
# Downloading https://cdn.servel.cl/padron/A14201.pdf
# Downloading https://cdn.servel.cl/padron/A14203.pdf
# Downloading https://cdn.servel.cl/padron/A14103.pdf
# Downloading https://cdn.servel.cl/padron/A14104.pdf
# Downloading https://cdn.servel.cl/padron/A14105.pdf
# Downloading https://cdn.servel.cl/padron/A14106.pdf
# Downloading https://cdn.servel.cl/padron/A14107.pdf
# Downloading https://cdn.servel.cl/padron/A14108.pdf
# Downloading https://cdn.servel.cl/padron/A14204.pdf
# Downloading https://cdn.servel.cl/padron/A14101.pdf
# Downloading https://cdn.servel.cl/padron/A10202.pdf
# Downloading https://cdn.servel.cl/padron/A10102.pdf
# Downloading https://cdn.servel.cl/padron/A10201.pdf
# Downloading https://cdn.servel.cl/padron/A10401.pdf
# Downloading https://cdn.servel.cl/padron/A10203.pdf
# Downloading https://cdn.servel.cl/padron/A10103.pdf
# Downloading https://cdn.servel.cl/padron/A10204.pdf
# Downloading https://cdn.servel.cl/padron/A10205.pdf
# Downloading https://cdn.servel.cl/padron/A10104.pdf
# Downloading https://cdn.servel.cl/padron/A10105.pdf
# Downloading https://cdn.servel.cl/padron/A10402.pdf
# Downloading https://cdn.servel.cl/padron/A10403.pdf
# Downloading https://cdn.servel.cl/padron/A10107.pdf
# Downloading https://cdn.servel.cl/padron/A10106.pdf
# Downloading https://cdn.servel.cl/padron/A10108.pdf
# Downloading https://cdn.servel.cl/padron/A10301.pdf
# Downloading https://cdn.servel.cl/padron/A10404.pdf
# Downloading https://cdn.servel.cl/padron/A10101.pdf
# Downloading https://cdn.servel.cl/padron/A10302.pdf
# Downloading https://cdn.servel.cl/padron/A10109.pdf
# Downloading https://cdn.servel.cl/padron/A10206.pdf
# Downloading https://cdn.servel.cl/padron/A10303.pdf
# Downloading https://cdn.servel.cl/padron/A10304.pdf
# Downloading https://cdn.servel.cl/padron/A10207.pdf
# Downloading https://cdn.servel.cl/padron/A10208.pdf
# Downloading https://cdn.servel.cl/padron/A10209.pdf
# Downloading https://cdn.servel.cl/padron/A10210.pdf
# Downloading https://cdn.servel.cl/padron/A10305.pdf
# Downloading https://cdn.servel.cl/padron/A10306.pdf
# Downloading https://cdn.servel.cl/padron/A10307.pdf
# Downloading https://cdn.servel.cl/padron/A11201.pdf
# Downloading https://cdn.servel.cl/padron/A11401.pdf
# Downloading https://cdn.servel.cl/padron/A11202.pdf
# Downloading https://cdn.servel.cl/padron/A11301.pdf
# Downloading https://cdn.servel.cl/padron/A11101.pdf
# Downloading https://cdn.servel.cl/padron/A11203.pdf
# Downloading https://cdn.servel.cl/padron/A11102.pdf
# Downloading https://cdn.servel.cl/padron/A11302.pdf
# Downloading https://cdn.servel.cl/padron/A11402.pdf
# Downloading https://cdn.servel.cl/padron/A11303.pdf
# Downloading https://cdn.servel.cl/padron/A12202.pdf
# Downloading https://cdn.servel.cl/padron/A12201.pdf
# Downloading https://cdn.servel.cl/padron/A12102.pdf
# Downloading https://cdn.servel.cl/padron/A12401.pdf
# Downloading https://cdn.servel.cl/padron/A12301.pdf
# Downloading https://cdn.servel.cl/padron/A12302.pdf
# Downloading https://cdn.servel.cl/padron/A12101.pdf
# Downloading https://cdn.servel.cl/padron/A12103.pdf
# Downloading https://cdn.servel.cl/padron/A12104.pdf
# Downloading https://cdn.servel.cl/padron/A12303.pdf
# Downloading https://cdn.servel.cl/padron/A12402.pdf
# End

# %%
import fitz
import pandas

doc = fitz.open('output/A06303.pdf') # Archivo origen
padron = []

for page in doc:
    print("Parsing Page " + str(page.number) + "/" + str(len(doc)))
    
    dic = page.getText("dict")

    # Campos están antecedidos por un dos puntos y espacio
    # ": DEL LIBERTADOR GENERAL BERNARDO O'HIGGINS"
    region = dic['blocks'][153]['lines'][1]['spans'][0]['text'][2:]
    provincia = dic['blocks'][154]['lines'][1]['spans'][0]['text'][2:]
    comuna = dic['blocks'][155]['lines'][1]['spans'][0]['text'][2:]

    # print(region, provincia, comuna)


    # Antes del bloque 156 se repite marca de agua SERVEL
    for block in dic['blocks'][157:]:
        # dependiendo de cuantas lineas tiene el bloque (parrafo) es como se interpreta el orden de los campos
        if len(block['lines']) == 6:
            nombre = block['lines'][0]['spans'][0]['text']
            ci = block['lines'][1]['spans'][0]['text']
            genero_direccion = block['lines'][2]['spans'][0]['text']
            gd_index = genero_direccion.find(' ')
            genero = genero_direccion[:gd_index]
            direccion = genero_direccion[gd_index+1:]
            circunscripcion = block['lines'][3]['spans'][0]['text']
            mesa = block['lines'][4]['spans'][0]['text']
            pueblo_indigena = block['lines'][5]['spans'][0]['text']

        else:
            nombre = block['lines'][0]['spans'][0]['text']
            ci = block['lines'][1]['spans'][0]['text']
            # ej: ' CONVENTO VIEJO 171 CALLE CONVENTO VIEJO CALLE CONVENTO VIEJO 171 CHIMBARONGO'
            genero_direccion = block['lines'][2]['spans'][0]['text']
            genero_index = genero_direccion.find(' ')
            genero = genero_direccion[:genero_index]
            direccion = genero_direccion[genero_index+1:]
            circunscripcion = block['lines'][3]['spans'][0]['text']
            mesa = block['lines'][4]['spans'][0]['text']
            pueblo_indigena = ""
        #print(nombre, ci, genero, direccion, circunscripcion, mesa, sep=',')

        padron.append({
            'Nombre': nombre,
            'CI': ci,
            'Genero': genero,
            'Direccion': direccion,
            'Circunscripcion': circunscripcion,
            'Mesa': mesa,
            'Region': region,
            'Provincia': provincia,
            'Comuna': comuna
            'Indigena': pueblo_indigena
        })
        
    #print('End page')

padron_df = pandas.DataFrame(padron)
padron_df.to_csv('./output_csv/A06303.csv', index=False) # CSV resultante

print('End')
# Out:
#   File "<ipython-input-5-51715157fa96>", line 58
#     'Indigena': pueblo_indigena
#              ^
# SyntaxError: invalid syntax
